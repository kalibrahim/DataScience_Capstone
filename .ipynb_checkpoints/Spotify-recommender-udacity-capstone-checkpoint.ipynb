# %% [markdown]
# # Building a Song Recommender
# I always had an imense love for music and I figured to channel my appreiciation for music into data science and take a shot at making song recommendation. I am using Spotify's dataset from Kaggle. I will leave a link to the dataset in the README.md doc.
# I don't expect this to be a walk in the park, as this is a new problem for me. I have never built a song recommendation engine before so this will be interesting to figure out.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import spotipy
import spotipy.util as util
import xgboost as xgb

from spotipy.oauth2 import SpotifyClientCredentials
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from hdbscan import HDBSCAN

# %%
client = '17a64fb26bab4b6f96fbbb31a04ce3f9'
secret = '741506f6590a47fdb4aaa3a060ee4c6b'
username = 'Khalid'
redirect_uri = 'https://developer.spotify.com/dashboard/applications/17a64fb26bab4b6f96fbbb31a04ce3f9'
scope = 'user-library-read playlist-modify-public playlist-read-private'

client_cred_manager = SpotifyClientCredentials(client_id=client, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager= client_cred_manager)
token = util.prompt_for_user_token(username, scope, client, secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for username: ", username)

# %%
def create_df(userID, playlistID):
    #load our playlist
    good_playlist = sp.user_playlist(userID, playlistID)
    songs = good_playlist["tracks"]["items"]

    #create an array of track ids (to find audio features) and create an array of song names
    track_ids = []
    song_names = []
    for i in songs:
        track_ids.append(i["track"]["id"])
        song_names.append(i["track"]["name"])

    #loop through to get audio features
    features = []
    for i in track_ids:
        for track in sp.audio_features(i):
            features.append(track)

    playlist_df = pd.DataFrame(features, index=song_names)
    return playlist_df

# %%
like_id = '4Bc92r2zL1zt22AikSodG4'
like_df = create_df(username, like_id)
like_df.head()
# Out:
#                       acousticness  \
# TIME                       0.00627
# Falling - Radio Edit       0.00752
# Space Between              0.01220
# Higher                     0.00810
# Together                   0.09850
#
#                                                            analysis_url  \
# TIME                  https://api.spotify.com/v1/audio-analysis/108r...
# Falling - Radio Edit  https://api.spotify.com/v1/audio-analysis/2jTJ...
# Space Between         https://api.spotify.com/v1/audio-analysis/72tb...
# Higher                https://api.spotify.com/v1/audio-analysis/4uQz...
# Together              https://api.spotify.com/v1/audio-analysis/48Cd...
#
#                       danceability  duration_ms  energy  \
# TIME                         0.768       166000   0.808
# Falling - Radio Edit         0.446       230551   0.928
# Space Between                0.702       199921   0.595
# Higher                       0.472       288189   0.881
# Together                     0.461       287370   0.848
#
#                                           id  instrumentalness  key  liveness  \
# TIME                  108r6pnZHStBIktpyyps9w          0.000005    5    0.3430
# Falling - Radio Edit  2jTJ9q2tLYJnElfIkiPwPZ          0.000019    0    0.5060
# Space Between         72tb3B98H3vAZIyR2MLA6p          0.472000   11    0.1080
# Higher                4uQzfUUpSPtP8378Qg5aTo          0.111000    6    0.3660
# Together              48CdOwO1Ense11v5a2Q4bm          0.000051    3    0.0784
#
#                       loudness  mode  speechiness    tempo  time_signature  \
# TIME                    -1.818     1       0.1120  119.971               4
# Falling - Radio Edit    -6.482     0       0.0907  127.012               4
# Space Between           -8.295     0       0.0356  124.007               5
# Higher                  -6.182     1       0.0491  127.014               4
# Together                -5.065     1       0.0692  128.009               4
#
#                                                              track_href  \
# TIME                  https://api.spotify.com/v1/tracks/108r6pnZHStB...
# Falling - Radio Edit  https://api.spotify.com/v1/tracks/2jTJ9q2tLYJn...
# Space Between         https://api.spotify.com/v1/tracks/72tb3B98H3vA...
# Higher                https://api.spotify.com/v1/tracks/4uQzfUUpSPtP...
# Together              https://api.spotify.com/v1/tracks/48CdOwO1Ense...
#
#                                 type                                   uri  \
# TIME                  audio_features  spotify:track:108r6pnZHStBIktpyyps9w
# Falling - Radio Edit  audio_features  spotify:track:2jTJ9q2tLYJnElfIkiPwPZ
# Space Between         audio_features  spotify:track:72tb3B98H3vAZIyR2MLA6p
# Higher                audio_features  spotify:track:4uQzfUUpSPtP8378Qg5aTo
# Together              audio_features  spotify:track:48CdOwO1Ense11v5a2Q4bm
#
#                       valence
# TIME                    0.664
# Falling - Radio Edit    0.239
# Space Between           0.483
# Higher                  0.240
# Together                0.278

# %%
like_playlist2_id = '5377x4KvJVl5Y4U6pakCf4'
like_playlist2_df = create_df(username, like_playlist2_id)
like_playlist2_df.head()
# Out:
#                     acousticness  \
# Snackbox                0.019500
# Telling Me              0.000404
# Thinking About You      0.009860
# Fine Day                0.026200
# Work That Catwalk       0.011500
#
#                                                          analysis_url  \
# Snackbox            https://api.spotify.com/v1/audio-analysis/5Vu4...
# Telling Me          https://api.spotify.com/v1/audio-analysis/4yVp...
# Thinking About You  https://api.spotify.com/v1/audio-analysis/57nH...
# Fine Day            https://api.spotify.com/v1/audio-analysis/5gjh...
# Work That Catwalk   https://api.spotify.com/v1/audio-analysis/7187...
#
#                     danceability  duration_ms  energy                      id  \
# Snackbox                   0.760       199695   0.896  5Vu4p96bMKfwyzEPBUJ4WQ
# Telling Me                 0.556       253048   0.943  4yVpJDlEuX2xN208YxKQea
# Thinking About You         0.664       192409   0.760  57nHZ3pR3pPL1AyE2fQphr
# Fine Day                   0.739       194967   0.865  5gjhnWVBIBgoWzv3SIQdwW
# Work That Catwalk          0.676       219840   0.976  7187K45RlXXDBPQ0FfDBaR
#
#                     instrumentalness  key  liveness  loudness  mode  \
# Snackbox                     0.26000    2     0.271    -3.276     1
# Telling Me                   0.09940    5     0.155    -5.997     0
# Thinking About You           0.01720   10     0.113    -7.725     0
# Fine Day                     0.00237    1     0.126    -4.670     0
# Work That Catwalk            0.44600    7     0.345    -4.120     1
#
#                     speechiness    tempo  time_signature  \
# Snackbox                 0.0671  124.986               4
# Telling Me               0.0372  123.979               4
# Thinking About You       0.0369  121.982               4
# Fine Day                 0.0460  124.977               4
# Work That Catwalk        0.0529  124.989               4
#
#                                                            track_href  \
# Snackbox            https://api.spotify.com/v1/tracks/5Vu4p96bMKfw...
# Telling Me          https://api.spotify.com/v1/tracks/4yVpJDlEuX2x...
# Thinking About You  https://api.spotify.com/v1/tracks/57nHZ3pR3pPL...
# Fine Day            https://api.spotify.com/v1/tracks/5gjhnWVBIBgo...
# Work That Catwalk   https://api.spotify.com/v1/tracks/7187K45RlXXD...
#
#                               type                                   uri  \
# Snackbox            audio_features  spotify:track:5Vu4p96bMKfwyzEPBUJ4WQ
# Telling Me          audio_features  spotify:track:4yVpJDlEuX2xN208YxKQea
# Thinking About You  audio_features  spotify:track:57nHZ3pR3pPL1AyE2fQphr
# Fine Day            audio_features  spotify:track:5gjhnWVBIBgoWzv3SIQdwW
# Work That Catwalk   audio_features  spotify:track:7187K45RlXXDBPQ0FfDBaR
#
#                     valence
# Snackbox              0.371
# Telling Me            0.226
# Thinking About You    0.115
# Fine Day              0.460
# Work That Catwalk     0.270

# %%
like_playlist3_id = '5CKGtvDsggH7g7UWhMqmSL'
like_playlist3_df = create_df(username, like_playlist3_id)
like_playlist3_df.head()
# Out:
#                                             acousticness  \
# Greensight - Edit                               0.001320
# Ceylon - Edit                                   0.000844
# Burning Heart - From "Rocky IV" Soundtrack      0.221000
# Albion - Estiva Remix                           0.001670
# Albion - Estiva Remix                           0.001670
#
#                                                                                  analysis_url  \
# Greensight - Edit                           https://api.spotify.com/v1/audio-analysis/3wud...
# Ceylon - Edit                               https://api.spotify.com/v1/audio-analysis/5fc1...
# Burning Heart - From "Rocky IV" Soundtrack  https://api.spotify.com/v1/audio-analysis/2ava...
# Albion - Estiva Remix                       https://api.spotify.com/v1/audio-analysis/3ApH...
# Albion - Estiva Remix                       https://api.spotify.com/v1/audio-analysis/3ApH...
#
#                                             danceability  duration_ms  energy  \
# Greensight - Edit                                  0.626       249609   0.740
# Ceylon - Edit                                      0.437       187852   0.803
# Burning Heart - From "Rocky IV" Soundtrack         0.651       230720   0.665
# Albion - Estiva Remix                              0.559       366667   0.961
# Albion - Estiva Remix                              0.559       366667   0.961
#
#                                                                 id  \
# Greensight - Edit                           3wud0u8mAupGeotcXcuPKO
# Ceylon - Edit                               5fc1ssHzrzAqEq8uGjKMrw
# Burning Heart - From "Rocky IV" Soundtrack  2avaSeKHI5l4sLruVfLdi2
# Albion - Estiva Remix                       3ApHpAUIxqPFASpzGPiSs1
# Albion - Estiva Remix                       3ApHpAUIxqPFASpzGPiSs1
#
#                                             instrumentalness  key  liveness  \
# Greensight - Edit                                   0.043000    3    0.2660
# Ceylon - Edit                                       0.063100    1    0.1320
# Burning Heart - From "Rocky IV" Soundtrack          0.000008    9    0.0403
# Albion - Estiva Remix                               0.774000    4    0.3110
# Albion - Estiva Remix                               0.774000    4    0.3110
#
#                                             loudness  mode  speechiness  \
# Greensight - Edit                             -7.204     0       0.0516
# Ceylon - Edit                                 -6.945     0       0.0605
# Burning Heart - From "Rocky IV" Soundtrack    -7.430     0       0.0269
# Albion - Estiva Remix                         -4.673     0       0.0583
# Albion - Estiva Remix                         -4.673     0       0.0583
#
#                                               tempo  time_signature  \
# Greensight - Edit                           128.011               4
# Ceylon - Edit                               127.970               4
# Burning Heart - From "Rocky IV" Soundtrack   97.996               4
# Albion - Estiva Remix                       126.002               4
# Albion - Estiva Remix                       126.002               4
#
#                                                                                    track_href  \
# Greensight - Edit                           https://api.spotify.com/v1/tracks/3wud0u8mAupG...
# Ceylon - Edit                               https://api.spotify.com/v1/tracks/5fc1ssHzrzAq...
# Burning Heart - From "Rocky IV" Soundtrack  https://api.spotify.com/v1/tracks/2avaSeKHI5l4...
# Albion - Estiva Remix                       https://api.spotify.com/v1/tracks/3ApHpAUIxqPF...
# Albion - Estiva Remix                       https://api.spotify.com/v1/tracks/3ApHpAUIxqPF...
#
#                                                       type  \
# Greensight - Edit                           audio_features
# Ceylon - Edit                               audio_features
# Burning Heart - From "Rocky IV" Soundtrack  audio_features
# Albion - Estiva Remix                       audio_features
# Albion - Estiva Remix                       audio_features
#
#                                                                              uri  \
# Greensight - Edit                           spotify:track:3wud0u8mAupGeotcXcuPKO
# Ceylon - Edit                               spotify:track:5fc1ssHzrzAqEq8uGjKMrw
# Burning Heart - From "Rocky IV" Soundtrack  spotify:track:2avaSeKHI5l4sLruVfLdi2
# Albion - Estiva Remix                       spotify:track:3ApHpAUIxqPFASpzGPiSs1
# Albion - Estiva Remix                       spotify:track:3ApHpAUIxqPFASpzGPiSs1
#
#                                             valence
# Greensight - Edit                             0.147
# Ceylon - Edit                                 0.039
# Burning Heart - From "Rocky IV" Soundtrack    0.647
# Albion - Estiva Remix                         0.480
# Albion - Estiva Remix                         0.480

# %%
like_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 58 entries, TIME to Be Someone - Cristoph Remix
# Data columns (total 18 columns):
# acousticness        58 non-null float64
# analysis_url        58 non-null object
# danceability        58 non-null float64
# duration_ms         58 non-null int64
# energy              58 non-null float64
# id                  58 non-null object
# instrumentalness    58 non-null float64
# key                 58 non-null int64
# liveness            58 non-null float64
# loudness            58 non-null float64
# mode                58 non-null int64
# speechiness         58 non-null float64
# tempo               58 non-null float64
# time_signature      58 non-null int64
# track_href          58 non-null object
# type                58 non-null object
# uri                 58 non-null object
# valence             58 non-null float64
# dtypes: float64(9), int64(4), object(5)
# memory usage: 8.6+ KB

# %%
dislike_id = ['37i9dQZF1DX1WSnLRtI26o', '37i9dQZEVXbLRQDuF5jeBp', '37i9dQZF1DWY4xHQp97fN6']
dislike_df = create_df(username, dislike_id)
dislike_df.head()
# Out:
#                                            acousticness  \
# Electricity (with Dua Lipa)                      0.0104
# Remind Me to Forget                              0.1930
# Close To Me (with Diplo) (feat. Swae Lee)        0.0969
# Flames                                           0.0723
# Memorized                                        0.3330
#
#                                                                                 analysis_url  \
# Electricity (with Dua Lipa)                https://api.spotify.com/v1/audio-analysis/5N4e...
# Remind Me to Forget                        https://api.spotify.com/v1/audio-analysis/5sIx...
# Close To Me (with Diplo) (feat. Swae Lee)  https://api.spotify.com/v1/audio-analysis/5JEx...
# Flames                                     https://api.spotify.com/v1/audio-analysis/33IO...
# Memorized                                  https://api.spotify.com/v1/audio-analysis/38LC...
#
#                                            danceability  duration_ms  energy  \
# Electricity (with Dua Lipa)                       0.588       238173   0.670
# Remind Me to Forget                               0.685       217287   0.508
# Close To Me (with Diplo) (feat. Swae Lee)         0.574       182623   0.758
# Flames                                            0.609       195000   0.726
# Memorized                                         0.547       206373   0.555
#
#                                                                id  \
# Electricity (with Dua Lipa)                5N4erncE7kuUccm7zEmwzk
# Remind Me to Forget                        5sIx4BlfYGuZeSLF40N9GH
# Close To Me (with Diplo) (feat. Swae Lee)  5JEx7HbmvHQQswJCsoo9rA
# Flames                                     33IOhptvC2Qoy2UhjiHXLV
# Memorized                                  38LC7jHjifqs5EnYUv4BgG
#
#                                            instrumentalness  key  liveness  \
# Electricity (with Dua Lipa)                        0.000003    0    0.3380
# Remind Me to Forget                                0.000000    0    0.1390
# Close To Me (with Diplo) (feat. Swae Lee)          0.000000    1    0.3950
# Flames                                             0.000008    5    0.0895
# Memorized                                          0.000313   11    0.1050
#
#                                            loudness  mode  speechiness  \
# Electricity (with Dua Lipa)                  -6.439     1       0.0473
# Remind Me to Forget                          -6.400     1       0.0987
# Close To Me (with Diplo) (feat. Swae Lee)    -5.029     0       0.0621
# Flames                                       -4.346     0       0.0414
# Memorized                                    -7.316     0       0.1630
#
#                                              tempo  time_signature  \
# Electricity (with Dua Lipa)                118.159               4
# Remind Me to Forget                         99.063               4
# Close To Me (with Diplo) (feat. Swae Lee)  144.111               4
# Flames                                      93.958               4
# Memorized                                   95.102               4
#
#                                                                                   track_href  \
# Electricity (with Dua Lipa)                https://api.spotify.com/v1/tracks/5N4erncE7kuU...
# Remind Me to Forget                        https://api.spotify.com/v1/tracks/5sIx4BlfYGuZ...
# Close To Me (with Diplo) (feat. Swae Lee)  https://api.spotify.com/v1/tracks/5JEx7HbmvHQQ...
# Flames                                     https://api.spotify.com/v1/tracks/33IOhptvC2Qo...
# Memorized                                  https://api.spotify.com/v1/tracks/38LC7jHjifqs...
#
#                                                      type  \
# Electricity (with Dua Lipa)                audio_features
# Remind Me to Forget                        audio_features
# Close To Me (with Diplo) (feat. Swae Lee)  audio_features
# Flames                                     audio_features
# Memorized                                  audio_features
#
#                                                                             uri  \
# Electricity (with Dua Lipa)                spotify:track:5N4erncE7kuUccm7zEmwzk
# Remind Me to Forget                        spotify:track:5sIx4BlfYGuZeSLF40N9GH
# Close To Me (with Diplo) (feat. Swae Lee)  spotify:track:5JEx7HbmvHQQswJCsoo9rA
# Flames                                     spotify:track:33IOhptvC2Qoy2UhjiHXLV
# Memorized                                  spotify:track:38LC7jHjifqs5EnYUv4BgG
#
#                                            valence
# Electricity (with Dua Lipa)                  0.505
# Remind Me to Forget                          0.315
# Close To Me (with Diplo) (feat. Swae Lee)    0.492
# Flames                                       0.362
# Memorized                                    0.575

# %%
like_df = like_df.drop(columns=["analysis_url", "id", "track_href", "type", "uri"])
dislike_df = dislike_df.drop(columns=["analysis_url", "id", "track_href", "type", "uri"])

# %%
sns.distplot(like_df['acousticness'],color ='blue', label='likes')
sns.distplot(dislike_df['acousticness'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %%
sns.distplot(like_df['loudness'],color ='blue', label='likes')
sns.distplot(dislike_df['loudness'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %%
sns.distplot(like_df['energy'],color ='blue', label='likes')
sns.distplot(dislike_df['energy'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %%
sns.distplot(like_df['instrumentalness'],color ='blue', label='likes')
sns.distplot(dislike_df['instrumentalness'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %%
sns.distplot(like_df['liveness'],color ='blue', label='likes')
sns.distplot(dislike_df['liveness'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %%
sns.distplot(like_df['speechiness'],color ='blue', label='likes')
sns.distplot(dislike_df['speechiness'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %%
sns.distplot(like_df['valence'],color ='blue', label='likes')
sns.distplot(dislike_df['valence'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %%
sns.distplot(like_df['time_signature'],color ='blue', label='likes')
sns.distplot(dislike_df['time_signature'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %%
def find_popularity(userID, playlistID):
    playlist = sp.user_playlist(userID, playlistID)
    songs = playlist["tracks"]["items"]
    popularity = []
    for i in songs:
        popularity.append(i["track"]["popularity"])
    return popularity

# %%
like_popularity = find_popularity(username, like_id)
dislike_popularity = find_popularity(username, dislike_id)

# %%
like_df['popularity'] = like_popularity
dislike_df['popularity'] = dislike_popularity
like_df.head()
# Out:
#                       acousticness  danceability  duration_ms  energy  \
# TIME                       0.00627         0.768       166000   0.808
# Falling - Radio Edit       0.00752         0.446       230551   0.928
# Space Between              0.01220         0.702       199921   0.595
# Higher                     0.00810         0.472       288189   0.881
# Together                   0.09850         0.461       287370   0.848
#
#                       instrumentalness  key  liveness  loudness  mode  \
# TIME                          0.000005    5    0.3430    -1.818     1
# Falling - Radio Edit          0.000019    0    0.5060    -6.482     0
# Space Between                 0.472000   11    0.1080    -8.295     0
# Higher                        0.111000    6    0.3660    -6.182     1
# Together                      0.000051    3    0.0784    -5.065     1
#
#                       speechiness    tempo  time_signature  valence  \
# TIME                       0.1120  119.971               4    0.664
# Falling - Radio Edit       0.0907  127.012               4    0.239
# Space Between              0.0356  124.007               5    0.483
# Higher                     0.0491  127.014               4    0.240
# Together                   0.0692  128.009               4    0.278
#
#                       popularity
# TIME                          63
# Falling - Radio Edit          27
# Space Between                 21
# Higher                        54
# Together                      33

# %%
dislike_df.head()
# Out:
#                                            acousticness  danceability  \
# Electricity (with Dua Lipa)                      0.0104         0.588
# Remind Me to Forget                              0.1930         0.685
# Close To Me (with Diplo) (feat. Swae Lee)        0.0969         0.574
# Flames                                           0.0723         0.609
# Memorized                                        0.3330         0.547
#
#                                            duration_ms  energy  \
# Electricity (with Dua Lipa)                     238173   0.670
# Remind Me to Forget                             217287   0.508
# Close To Me (with Diplo) (feat. Swae Lee)       182623   0.758
# Flames                                          195000   0.726
# Memorized                                       206373   0.555
#
#                                            instrumentalness  key  liveness  \
# Electricity (with Dua Lipa)                        0.000003    0    0.3380
# Remind Me to Forget                                0.000000    0    0.1390
# Close To Me (with Diplo) (feat. Swae Lee)          0.000000    1    0.3950
# Flames                                             0.000008    5    0.0895
# Memorized                                          0.000313   11    0.1050
#
#                                            loudness  mode  speechiness  \
# Electricity (with Dua Lipa)                  -6.439     1       0.0473
# Remind Me to Forget                          -6.400     1       0.0987
# Close To Me (with Diplo) (feat. Swae Lee)    -5.029     0       0.0621
# Flames                                       -4.346     0       0.0414
# Memorized                                    -7.316     0       0.1630
#
#                                              tempo  time_signature  valence  \
# Electricity (with Dua Lipa)                118.159               4    0.505
# Remind Me to Forget                         99.063               4    0.315
# Close To Me (with Diplo) (feat. Swae Lee)  144.111               4    0.492
# Flames                                      93.958               4    0.362
# Memorized                                   95.102               4    0.575
#
#                                            popularity
# Electricity (with Dua Lipa)                        81
# Remind Me to Forget                                76
# Close To Me (with Diplo) (feat. Swae Lee)          85
# Flames                                             77
# Memorized                                          61

# %%
sns.distplot(like_df['popularity'], color='b', label='likes')
sns.distplot(dislike_df['popularity'], color='r', label='dislikes')
plt.legend()
plt.show()

# %%
def find_explicit(userID, playlistID):
    playlist = sp.user_playlist(userID, playlistID)
    songs = playlist['tracks']['items']
    popularity = []
    for i in songs:
        popularity.append(i['track']['explicit'])
    return popularity

# %%
like_explicit = find_explicit(username, like_id)
dislike_explicit = find_explicit(username, dislike_id)

# %%
like_df['explicit'] = like_explicit
dislike_df['explicit'] = dislike_explicit
like_df.tail()
# Out:
#                                          acousticness  danceability  \
# Doberman                                       0.0223         0.535
# Sweet Disposition - Cristoph Remix Edit        0.0365         0.586
# Those Were the Days - Cristoph Remix           0.0824         0.684
# Slowly Burning 2019                            0.0910         0.636
# Be Someone - Cristoph Remix                    0.0386         0.618
#
#                                          duration_ms  energy  \
# Doberman                                      180960   0.986
# Sweet Disposition - Cristoph Remix Edit       257225   0.867
# Those Were the Days - Cristoph Remix          372251   0.822
# Slowly Burning 2019                           242184   0.905
# Be Someone - Cristoph Remix                   217016   0.878
#
#                                          instrumentalness  key  liveness  \
# Doberman                                            0.779    6    0.7430
# Sweet Disposition - Cristoph Remix Edit             0.788    1    0.0720
# Those Were the Days - Cristoph Remix                0.574   10    0.0917
# Slowly Burning 2019                                 0.422    4    0.1050
# Be Someone - Cristoph Remix                         0.610    5    0.1120
#
#                                          loudness  mode  speechiness    tempo  \
# Doberman                                   -4.919     1       0.0711  124.975
# Sweet Disposition - Cristoph Remix Edit    -6.246     0       0.0430  125.992
# Those Were the Days - Cristoph Remix       -6.203     0       0.0500  125.007
# Slowly Burning 2019                        -5.149     0       0.0453  124.974
# Be Someone - Cristoph Remix                -7.072     0       0.0458  124.985
#
#                                          time_signature  valence  popularity  \
# Doberman                                              4    0.362          47
# Sweet Disposition - Cristoph Remix Edit               4    0.353          36
# Those Were the Days - Cristoph Remix                  4    0.351          29
# Slowly Burning 2019                                   4    0.357          51
# Be Someone - Cristoph Remix                           4    0.552          50
#
#                                          explicit
# Doberman                                    False
# Sweet Disposition - Cristoph Remix Edit     False
# Those Were the Days - Cristoph Remix        False
# Slowly Burning 2019                         False
# Be Someone - Cristoph Remix                 False

# %%
dislike_df.head()
# Out:
#                                            acousticness  danceability  \
# Electricity (with Dua Lipa)                      0.0104         0.588
# Remind Me to Forget                              0.1930         0.685
# Close To Me (with Diplo) (feat. Swae Lee)        0.0969         0.574
# Flames                                           0.0723         0.609
# Memorized                                        0.3330         0.547
#
#                                            duration_ms  energy  \
# Electricity (with Dua Lipa)                     238173   0.670
# Remind Me to Forget                             217287   0.508
# Close To Me (with Diplo) (feat. Swae Lee)       182623   0.758
# Flames                                          195000   0.726
# Memorized                                       206373   0.555
#
#                                            instrumentalness  key  liveness  \
# Electricity (with Dua Lipa)                        0.000003    0    0.3380
# Remind Me to Forget                                0.000000    0    0.1390
# Close To Me (with Diplo) (feat. Swae Lee)          0.000000    1    0.3950
# Flames                                             0.000008    5    0.0895
# Memorized                                          0.000313   11    0.1050
#
#                                            loudness  mode  speechiness  \
# Electricity (with Dua Lipa)                  -6.439     1       0.0473
# Remind Me to Forget                          -6.400     1       0.0987
# Close To Me (with Diplo) (feat. Swae Lee)    -5.029     0       0.0621
# Flames                                       -4.346     0       0.0414
# Memorized                                    -7.316     0       0.1630
#
#                                              tempo  time_signature  valence  \
# Electricity (with Dua Lipa)                118.159               4    0.505
# Remind Me to Forget                         99.063               4    0.315
# Close To Me (with Diplo) (feat. Swae Lee)  144.111               4    0.492
# Flames                                      93.958               4    0.362
# Memorized                                   95.102               4    0.575
#
#                                            popularity  explicit
# Electricity (with Dua Lipa)                        81     False
# Remind Me to Forget                                76     False
# Close To Me (with Diplo) (feat. Swae Lee)          85      True
# Flames                                             77     False
# Memorized                                          61     False

# %%
like_df['like/dislike'] = [1] * (len(like_df))
dislike_df['like/dislike'] = [0] * (len(dislike_df))
like_df.head()
# Out:
#                       acousticness  danceability  duration_ms  energy  \
# TIME                       0.00627         0.768       166000   0.808
# Falling - Radio Edit       0.00752         0.446       230551   0.928
# Space Between              0.01220         0.702       199921   0.595
# Higher                     0.00810         0.472       288189   0.881
# Together                   0.09850         0.461       287370   0.848
#
#                       instrumentalness  key  liveness  loudness  mode  \
# TIME                          0.000005    5    0.3430    -1.818     1
# Falling - Radio Edit          0.000019    0    0.5060    -6.482     0
# Space Between                 0.472000   11    0.1080    -8.295     0
# Higher                        0.111000    6    0.3660    -6.182     1
# Together                      0.000051    3    0.0784    -5.065     1
#
#                       speechiness    tempo  time_signature  valence  \
# TIME                       0.1120  119.971               4    0.664
# Falling - Radio Edit       0.0907  127.012               4    0.239
# Space Between              0.0356  124.007               5    0.483
# Higher                     0.0491  127.014               4    0.240
# Together                   0.0692  128.009               4    0.278
#
#                       popularity  explicit  like/dislike
# TIME                          63     False             1
# Falling - Radio Edit          27     False             1
# Space Between                 21     False             1
# Higher                        54     False             1
# Together                      33     False             1

# %%
#concate
train_data = pd.concat([like_df, dislike_df])
train_data
# Out:
#                                                     acousticness  \
# TIME                                                    0.006270
# Falling - Radio Edit                                    0.007520
# Space Between                                           0.012200
# Higher                                                  0.008100
# Together                                                0.098500
# Shadows                                                 0.005820
# Northern Lights                                         0.018900
# Lust                                                    0.002000
# Deep Inside                                             0.039900
# 365 - Zedd Remix                                        0.004760
# IOU (feat. Emilie Brandt) - Jason Ross Club Mix         0.005390
# Been A Long Time                                        0.018500
# Méduse                                                  0.021200
# Now Or Never                                            0.007820
# Cycles (ABGT321)                                        0.000340
# Young Folks                                           0    0.1010    -6.011
# Too Little Too Late - 2018                            6    0.1860    -4.304
# Would I Lie To You? - Edit                           11    0.1630    -7.827
# How Do We Make It                                     4    0.0729    -8.502
# With You                                              2    0.1060    -6.210
# (I Just) Died In Your Arms                           11    0.0678   -11.209
# Mr. Brightside                                        1    0.0926    -3.660
# Meant to Be (feat. Florida Georgia Line)             10    0.0830    -6.458
# Escapade                                              1    0.0917    -4.751
# Light Me Up                                           6    0.1020    -7.886
# Style                                                 7    0.1180    -5.595
# Crush                                                 1    0.0890    -5.568
# Makes Me Wonder                                       4    0.0568    -2.425
#
#                                                     mode  speechiness  \
# TIME                                                   1       0.1120
# Falling - Radio Edit                                   0       0.0907
# Space Between                                          0       0.0356
# Higher                                                 1       0.0491
# Together                                               1       0.0692
# Shadows                                                1       0.0673
# Northern Lights                                        0       0.0490
# Lust                                                   1       0.2790
# Deep Inside                                            1       0.0421
# 365 - Zedd Remix                                       1       0.0413
# IOU (feat. Emilie Brandt) - Jason Ross Club Mix        0       0.1390
# Been A Long Time                                       1       0.0406
# Méduse                                                 1       0.0416
# Now Or Never                                           1       0.0415
# Cycles (ABGT321)                                       0       0.0390
# The Lights                                             1       0.0409
# Elements - Dimibo Remix                                1       0.0643
# All Day And Night - Jax Jones & Martin Solveig ...     0       0.0897
# Into Clouds - Lauer Remix                              0       0.0395
# Into Clouds - Marsh Remix                              0       0.0409
# Pray (feat. Kameron Alexander)                         0       0.0395
# Sneaking Hotdogs into People's Pockets - Radio ...     1       0.0297
# There's Only You (ASOT 908) - Above & Beyond Cl...     0       0.0479
# REDLIGHT                                               0       0.3540
# YUCK                                                   1       0.2380
# Hold You Tight                                         0       0.0599
# Freefall                                               1       0.0490
# The Blood                                              0       0.0942
# Omega (feat. Ibranovski)                               1       0.0855
# Don't Give Up On Me                                    0       0.1420
# ...                                                  ...          ...
# Fool For Waiting                                       1       0.0358
# Together Again                                         1       0.1020
# Rather Be (feat. Jess Glynne)                          1       0.0377
# Don't Be Stupid (You Know I Love You)                  1       0.0319
# Safe And Sound                                         1       0.0325
# Can't Get You out of My Head                           0       0.0339
# Don't Stop                                             1       0.0353
# I Believe in Us                                        1       0.0440
# Faded                                                  0       0.0489
# Tell Me Smooth                                         0       0.0449
# Something In The Way You Move                          0       0.0493
# Virtual Insanity - Remastered                          1       0.1050
# Never Let You Go - 2008 Version                        1       0.0368
# Everywhere                                             1       0.0762
# The Space Between                                      1       0.0315
# Slide                                                  1       0.0374
# Double Shifts                                          1       0.2430
# Young Folks                                            1       0.0391
# Too Little Too Late - 2018                             0       0.0404
# Would I Lie To You? - Edit                             0       0.0337
# How Do We Make It                                      1       0.0544
# With You                                               1       0.0792
# (I Just) Died In Your Arms                             0       0.0438
# Mr. Brightside                                         1       0.0917
# Meant to Be (feat. Florida Georgia Line)               1       0.0856
# Escapade                                               1       0.0521
# Light Me Up                                            1       0.0401
# Style                                                  1       0.0402
# Crush                                                  0       0.0298
# Makes Me Wonder                                        0       0.0357
#
#                                                       tempo  time_signature  \
# TIME                                                119.971               4
# Falling - Radio Edit                                127.012               4
# Space Between                                       124.007               5
# Higher                                              127.014               4
# Together                                            128.009               4
# Shadows                                             126.991               4
# Northern Lights                                     127.913               4
# Lust                                                124.976               4
# Deep Inside                                         123.951               4
# 365 - Zedd Remix                                    124.019               4
# IOU (feat. Emilie Brandt) - Jason Ross Club Mix     127.937               4
# Been A Long Time                                    123.997               4
# Méduse                                              122.998               4
# Now Or Never                                        121.983               4
# Cycles (ABGT321)                                    130.009               4
# The Lights                                          127.002               4
# Elements - Dimibo Remix                             139.985               4
# All Day And Night - Jax Jones & Martin Solveig ...  121.908               4
# Into Clouds - Lauer Remix                           123.023               4
# Into Clouds - Marsh Remix                           122.987               4
# Pray (feat. Kameron Alexander)                      145.937               4
# Sneaking Hotdogs into People's Pockets - Radio ...  127.981               4
# There's Only You (ASOT 908) - Above & Beyond Cl...  127.990               4
# REDLIGHT                                            129.903               3
# YUCK                                                149.990               4
# Hold You Tight                                      123.995               4
# Freefall                                            129.975               4
# The Blood                                           112.450               3
# Omega (feat. Ibranovski)                            124.996               4
# Don't Give Up On Me                                 117.957               4
# ...                                                     ...             ...
# Fool For Waiting                                     92.080               4
# Together Again                                      123.091               4
# Rather Be (feat. Jess Glynne)                       120.970               4
# Don't Be Stupid (You Know I Love You)               122.002               4
# Safe And Sound                                      117.948               5
# Can't Get You out of My Head                        126.007               4
# Don't Stop                                          118.965               4
# I Believe in Us                                     137.044               4
# Faded                                               107.961               4
# Tell Me Smooth                                       98.026               4
# Something In The Way You Move                       109.004               4
# Virtual Insanity - Remastered                        92.025               4
# Never Let You Go - 2008 Version                     113.760               4
# Everywhere                                           96.952               4
# The Space Between                                   170.032               4
# Slide                                               112.423               4
# Double Shifts                                        80.125               4
# Young Folks                                         138.164               4
# Too Little Too Late - 2018                           82.764               4
# Would I Lie To You? - Edit                          101.089               4
# How Do We Make It                                   139.069               4
# With You                                             97.998               4
# (I Just) Died In Your Arms                          124.919               4
# Mr. Brightside                                      148.112               4
# Meant to Be (feat. Florida Georgia Line)            154.084               4
# Escapade                                            115.219               4
# Light Me Up                                         147.963               4
# Style                                                94.933               4
# Crush                                               115.037               4
# Makes Me Wonder                                     113.993               4
#
#                                                     valence  popularity  \
# TIME                                                 0.6640          63
# Falling - Radio Edit                                 0.2390          27
# Space Between                                        0.4830          21
# Higher                                               0.2400          54
# Together                                             0.2780          33
# Shadows                                              0.0792          27
# Northern Lights                                      0.3000          40
# Lust                                                 0.4730          28
# Deep Inside                                          0.1490          35
# 365 - Zedd Remix                                     0.1830          54
# IOU (feat. Emilie Brandt) - Jason Ross Club Mix      0.1980          27
# Been A Long Time                                     0.7340          41
# Méduse                                               0.1310          42
# Now Or Never                                         0.6230          36
# Cycles (ABGT321)                                     0.2050          18
# The Lights                                           0.1590          55
# Elements - Dimibo Remix                              0.1500           6
# All Day And Night - Jax Jones & Martin Solveig ...   0.5210          77
# Into Clouds - Lauer Remix                            0.2000          23
# Something In The Way You Move                          False             0
# Virtual Insanity - Remastered                          False             0
# Never Let You Go - 2008 Version                        False             0
# Everywhere                                             False             0
# The Space Between                                      False             0
# Slide                                                  False             0
# Double Shifts                                          False             0
# Young Folks                                            False             0
# Too Little Too Late - 2018                             False             0
# Would I Lie To You? - Edit                             False             0
# How Do We Make It                                      False             0
# With You                                               False             0
# (I Just) Died In Your Arms                             False             0
# Mr. Brightside                                         False             0
# Meant to Be (feat. Florida Georgia Line)               False             0
# Escapade                                               False             0
# Light Me Up                                            False             0
# Style                                                  False             0
# Crush                                                  False             0
# Makes Me Wonder                                         True             0
#
# [158 rows x 16 columns]

# %%
train, test = train_test_split(train_data, test_size = 0.3, random_state = 42)
train.head()
# Out:
#                                    acousticness  danceability  duration_ms  \
# Everywhere                             0.013600         0.523       214827
# Been A Long Time                       0.018500         0.673       186774
# Say Something                          0.103000         0.707       278893
# Lost In Your Light (feat. Miguel)      0.000402         0.646       203769
# Fascination                            0.000285         0.491       181667
#
#                                    energy  instrumentalness  key  liveness  \
# Everywhere                          0.828          0.000255    1    0.1650
# Been A Long Time                    0.725          0.002440    1    0.0819
# Say Something                       0.632          0.000011   10    0.0841
# Lost In Your Light (feat. Miguel)   0.772          0.000000    2    0.1020
# Fascination                         0.831          0.000079    6    0.0761
#
#                                    loudness  mode  speechiness    tempo  \
# Everywhere                           -4.696     1       0.0762   96.952
# Been A Long Time                     -7.083     1       0.0406  123.997
# Say Something                        -7.031     1       0.0789   97.040
# Lost In Your Light (feat. Miguel)    -3.826     1       0.0564  117.097
# Fascination                          -5.321     0       0.0349  193.968
#
#                                    time_signature  valence  popularity  \
# Everywhere                                      4    0.476          66
# Been A Long Time                                4    0.734          41
# Say Something                                   4    0.372          74
# Lost In Your Light (feat. Miguel)               4    0.414          55
# Fascination                                     4    0.828          14
#
#                                    explicit  like/dislike
# Everywhere                            False             0
# Been A Long Time                      False             1
# Say Something                         False             0
# Lost In Your Light (feat. Miguel)     False             0
# Fascination                           False             0

# %%
plt.figure(figsize=(12,12))
ax = sns.heatmap(train.corr(),annot=True , cmap='winter')

# %%
feats = ['acousticness', 'instrumentalness', 'liveness', 'loudness', 'energy', 
         'danceability', 'speechiness', 'valence', 'popularity', 'tempo']
X_train = train[feats]
y_train = train['like/dislike']
X_test = test[feats]
y_test = test['like/dislike']

# %%
#logistic regression
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
lr.score(X_test, y_test)
# Out:
# /Users/khalid/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.8333333333333334

# %%
#KNeighbors
knn = KNeighborsClassifier(5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
knn.score(X_test, y_test)
# Out:
# 0.8125

# %%
#RandomForest
rf = RandomForestClassifier(max_depth=5, n_estimators=10, max_features=2)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
rf.score(X_test, y_test)
# Out:
# 0.9166666666666666

# %%
#DecisonTree
dt = DecisionTreeClassifier(min_samples_split=90)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
dt.score(X_test, y_test)
# Out:
# 0.7291666666666666

# %%
#Xgboost
xg = xgb.XGBClassifier(n_estimators=100, max_depth=5, learning_rate=0.1, subsample=0.5)
xg.fit(X_train, y_train)
y_pred = xg.predict(X_test)
xg.score(X_test, y_test)
# Out:
# 0.9375

# %%
X_train_scaled = MinMaxScaler().fit_transform(X_train)

X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns, index=X_train.index)

# %%
dummy_pca = PCA(n_components=0.95, random_state=42).fit(X_train_scaled)

print("PCA has {} comps".format(dummy_pca.n_components_))
print("Variance is {}".format(sum(dummy_pca.explained_variance_ratio_)))
# Out:
# PCA has 8 comps
# Variance is 0.9575818854825553

# %%
hdbs = HDBSCAN(
    prediction_data=True,
    core_dist_n_jobs=3,
    min_cluster_size=2).fit(dummy_pca)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-8fb774a059d7> in <module>
#       2     prediction_data=True,
#       3     core_dist_n_jobs=3,
# ----> 4     min_cluster_size=2).fit(dummy_pca)
#
# ~/anaconda3/lib/python3.7/site-packages/hdbscan/hdbscan_.py in fit(self, X, y)
#     870         """
#     871         if self.metric != 'precomputed':
# --> 872             X = check_array(X, accept_sparse='csr')
#     873             self._raw_data = X
#     874         elif issparse(X):
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     512                     "Reshape your data either using array.reshape(-1, 1) if "
#     513                     "your data has a single feature or array.reshape(1, -1) "
# --> 514                     "if it contains a single sample.".format(array))
#     515             # If input is 1D raise error
#     516             if array.ndim == 1:
#
# ValueError: Expected 2D array, got scalar array instead:
# array=PCA(copy=True, iterated_power='auto', n_components=0.95, random_state=42,
#     svd_solver='auto', tol=0.0, whiten=False).
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %% [markdown]
# ### Let's explore the features

# %%
#Artists with the highest presence in this set
df['artists'].value_counts().head(10)
# Out:
# XXXTENTACION     6
# Post Malone      6
# Drake            4
# Marshmello       3
# Ed Sheeran       3
# Khalid           2
# Ozuna            2
# The Weeknd       2
# Ariana Grande    2
# Dua Lipa         2
# Name: artists, dtype: int64

# %%
#Lets plot the danceability column
sns.set_style(style='whitegrid')
sns.distplot(df['danceability'],hist=True, kde=True)

# %% [markdown]
# We can see that the distribution of songs is considerd dancable, which the majority seem to score from 0.6 to 0.8. To make our analysis better lets divide them into 3 groups
# * =>75% -- Very danceable 💃🏽
# * Inbetween 74% and 50% - danceable 🕺🏽
# * <50% -- non-danceable 👩🏽‍🎤

# %%
vd = df['danceability']>=0.75
ld = (df['danceability']>=0.5) & (df['danceability']< 0.75)
nd = df['danceability']<-0.5

# %%
#lets analyze the enery of songs
sns.distplot(df['energy'])

# %%
#Lets analyze the correlation of the most important features 
correlation_df = df[['danceability', 'energy', 'valence', 'loudness', 'tempo']]

# %%
sns.heatmap(correlation_df.corr(), annot=True, cmap='Purples')

# %%
sns.jointplot(data=correlation_df, y='energy', x='loudness',kind='reg')

# %% [markdown]
# ## Musical Tempo
# Music tempo is the amount of beats per minute or as known as BPM. Different music genres have different BPMs
# Generally speaking each of these genres have these equavlent BPMs
#
# | Genre | Tempo/BPM |
# | --- | --- |
# | Reggae | 60-90 BPM |
# | Hip-hop | 85-95 BPM|
# | Pop | 100-130 BPM |
# | Rock | 110 - 140 |
# | Glitch hop | 105-115 BPM |
# | House | 118-135 BPM |
# | Tech House | 120-135 BPM |
# | Techno | 120-125 BPM |
# | Electro House | 125-130 BPM |
# | Trance | 130-145 BPM |
# | Dubstep | 140+ BPM |
# | Drum & Bass | 165-185 BPM |

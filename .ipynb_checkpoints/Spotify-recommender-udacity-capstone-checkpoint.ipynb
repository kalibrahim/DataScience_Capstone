# %% [markdown]
# # Building a Song Recommender
# I always had an imense love for music and I figured to channel my appreiciation for music into data science and take a shot at making song recommendation. I am using Spotify's dataset from Kaggle. I will leave a link to the dataset in the README.md doc.
# I don't expect this to be a walk in the park, as this is a new problem for me. I have never built a song recommendation engine before so this will be interesting to figure out.

# %% [markdown]
# ## Setup
# I am using Spotify's API to import my playlist into this notebook. https://developer.spotify.com/dashboard/login. Use my client ID and secert to run this notebook.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import spotipy
import spotipy.util as util
import xgboost as xgb

from spotipy.oauth2 import SpotifyClientCredentials
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Musical Tempo
# Music tempo is the amount of beats per minute or as known as BPM. Different music genres have different BPMs
# Generally speaking each of these genres have these equavlent BPMs
#
# | Genre | Tempo/BPM |
# | --- | --- |
# | Reggae | 60-90 BPM |
# | Hip-hop | 85-95 BPM|
# | Pop | 100-130 BPM |
# | Rock | 110 - 140 |
# | Glitch hop | 105-115 BPM |
# | House | 118-135 BPM |
# | Tech House | 120-135 BPM |
# | Techno | 120-125 BPM |
# | Electro House | 125-130 BPM |
# | Trance | 130-145 BPM |
# | Dubstep | 140+ BPM |
# | Drum & Bass | 165-185 BPM |

# %%
#Login and auth token
client = '17a64fb26bab4b6f96fbbb31a04ce3f9'
secret = '741506f6590a47fdb4aaa3a060ee4c6b'
username = 'Khalid'
redirect_uri = 'https://developer.spotify.com/dashboard/applications/17a64fb26bab4b6f96fbbb31a04ce3f9'
scope = 'user-library-read playlist-modify-public playlist-read-private'

client_cred_manager = SpotifyClientCredentials(client_id=client, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager= client_cred_manager)
token = util.prompt_for_user_token(username, scope, client, secret, redirect_uri)

if token:
    sp = spotipy.Spotify(auth=token)
else:
    print("Can't get token for username: ", username)

# %% [markdown]
# Load the playlist from our Spotify library using Spotipy's package into a dataframe. We're going to pull information about each song such as danceablity, energy, acousticness, etc. We will be using these features to run our model. To read more about these features use this link: https://developer.spotify.com/documentation/web-api/reference/object-model/#audio-features-object

# %%
def create_df(userID, playlistID):
    '''
    Function to get all songs of username from a specific playlistID and
    load it into a DF
    
    Args: 
        userID (str): Spotify username
        playlistID (str): Spotify playlist ID
        
    Return:
        playlist (pd DataFrame): dataframe of loaded playlist. 
    '''
    #load playlist
    good_playlist = sp.user_playlist(userID, playlistID)
    songs = good_playlist["tracks"]["items"]

    #an array of track ids (to find audio features) and create an array of song names
    track_ids = []
    song_names = []
    for i in songs:
        track_ids.append(i["track"]["id"])
        song_names.append(i["track"]["name"])

    #loop through to get audio features
    features = []
    for i in track_ids:
        for track in sp.audio_features(i):
            features.append(track)

    playlist_df = pd.DataFrame(features, index=song_names)
    return playlist_df

# %% [markdown]
# ## Feature Engineering
# Let's add new features to our dataframes, we can improve our modeling score by add features such as expoclit lyics, popularity and then combining it all in one final dataframe.

# %%
def find_popularity(userID, playlistID):
    '''
    Function to find song's popularity, pull this inforamtion from spotipy 
    
    Args:
        userID (str): Spotify's username
        playlistID (str): Spotifly's playlist ID
    returns:
        popularity (int): popularity score 0-100
    '''
    
    playlist = sp.user_playlist(userID, playlistID)
    songs = playlist["tracks"]["items"]
    popularity = []
    for i in songs:
        popularity.append(i["track"]["popularity"])
    return popularity

# %%
def find_explicit(userID, playlistID):
    '''
    Function to create an explicit feature pull from Spotify's API
    
    Args:
        userID (str): Spotify username
        playlistID (str): Spotify playlist ID
    
    return:
        explicit (Bool): If song is explicit = True else False
    '''
    playlist = sp.user_playlist(userID, playlistID)
    songs = playlist['tracks']['items']
    explicit = []
    for i in songs:
        explicit.append(i['track']['explicit'])
    return explicit

# %% [markdown]
# Load a couple of playlists into different dataframes and combine them in the end to the a mix of songs that I like. Do the same thing for songs that I dislike.

# %%
like_id = '4Bc92r2zL1zt22AikSodG4'
like_df = create_df(username, like_id)

like_playlist2_id = '5377x4KvJVl5Y4U6pakCf4'
like_playlist2_df = create_df(username, like_playlist2_id)

like_playlist3_id = '5CKGtvDsggH7g7UWhMqmSL'
like_playlist3_df = create_df(username, like_playlist3_id)

like_playlist4_id = '37i9dQZF1DX4dyzvuaRJ0n'
like_playlist4_df = create_df(username, like_playlist4_id)

like_playlist5_id = '37i9dQZEVXcLdkjxsUOkZD'
like_playlist5_df = create_df(username, like_playlist5_id)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     118         try:
# --> 119             r.raise_for_status()
#     120         except:
#
# ~/anaconda3/lib/python3.7/site-packages/requests/models.py in raise_for_status(self)
#     939         if http_error_msg:
# --> 940             raise HTTPError(http_error_msg, response=self)
#     941
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api.spotify.com/v1/audio-features/?ids=71TQa6LP7K9PlU9AGkIpHx
#
# During handling of the above exception, another exception occurred:
#
# SpotifyException                          Traceback (most recent call last)
# <ipython-input-28-b5533f15439b> in <module>
#       1 like_id = '4Bc92r2zL1zt22AikSodG4'
# ----> 2 like_df = create_df(username, like_id)
#       3
#       4 like_playlist2_id = '5377x4KvJVl5Y4U6pakCf4'
#       5 like_playlist2_df = create_df(username, like_playlist2_id)
#
# <ipython-input-25-4f6299e2d4e4> in create_df(userID, playlistID)
#      25     features = []
#      26     for i in track_ids:
# ---> 27         for track in sp.audio_features(i):
#      28             features.append(track)
#      29
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in audio_features(self, tracks)
#     824         if isinstance(tracks, str):
#     825             trackid = self._get_id('track', tracks)
# --> 826             results = self._get('audio-features/?ids=' + trackid)
#     827         else:
#     828             tlist = [self._get_id('track', t) for t in tracks]
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# ~/anaconda3/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     122                 raise SpotifyException(r.status_code,
#     123                     -1, '%s:\n %s' % (r.url, r.json()['error']['message']),
# --> 124                     headers=r.headers)
#     125             else:
#     126                 raise SpotifyException(r.status_code,
#
# SpotifyException: http status: 401, code:-1 - https://api.spotify.com/v1/audio-features/?ids=71TQa6LP7K9PlU9AGkIpHx:
#  The access token expired

# %%
dislike_id = '37i9dQZF1DX1WSnLRtI26o'
dislike_df = create_df(username, dislike_id)

dislike_playlist2_id = '37i9dQZEVXbLRQDuF5jeBp'
dislike_playlist2_df = create_df(username, dislike_playlist2_id)

dislike_playlist3_id = '37i9dQZF1DWY4xHQp97fN6'
dislike_playlist3_df = create_df(username, dislike_playlist3_id)

dislike_playlist4_id = '37i9dQZF1DXcBWIGoYBM5M'
dislike_playlist4_df = create_df(username, dislike_playlist4_id)

dislike_playlist5_id = '37i9dQZF1DX1lVhptIYRda'
dislike_playlist5_df = create_df(username, dislike_playlist5_id)

# %%
like_popularity = find_popularity(username, like_id)
like_popularity2 = find_popularity(username, like_playlist2_id)
like_popularity3 = find_popularity(username, like_playlist3_id)
like_popularity4 = find_popularity(username, like_playlist4_id)
like_popularity5 = find_popularity(username, like_playlist5_id)

dislike_popularity = find_popularity(username, dislike_id)
dislike_popularity2 = find_popularity(username, dislike_playlist2_id)
dislike_popularity3 = find_popularity(username, dislike_playlist3_id)
dislike_popularity4 = find_popularity(username, dislike_playlist4_id)
dislike_popularity5 = find_popularity(username, dislike_playlist5_id)

# %%
like_df['popularity'] = like_popularity
like_playlist2_df['popularity'] = like_popularity2
like_playlist3_df['popularity'] = like_popularity3
like_playlist4_df['popularity'] = like_popularity4
like_playlist5_df['popularity'] = like_popularity5

dislike_df['popularity'] = dislike_popularity
dislike_playlist2_df['popularity'] = dislike_popularity2
dislike_playlist3_df['popularity'] = dislike_popularity3
dislike_playlist4_df['popularity'] = dislike_popularity4
dislike_playlist5_df['popularity'] = dislike_popularity5

# %%
like_explicit = find_explicit(username, like_id)
like_explicit2 = find_explicit(username, like_playlist2_id)
like_explicit3 = find_explicit(username, like_playlist3_id)
like_explicit4 = find_explicit(username, like_playlist4_id)
like_explicit5 = find_explicit(username, like_playlist5_id)

dislike_explicit = find_explicit(username, dislike_id)
dislike_explicit2 = find_explicit(username, dislike_playlist2_id)
dislike_explicit3 = find_explicit(username, dislike_playlist3_id)
dislike_explicit4 = find_explicit(username, dislike_playlist4_id)
dislike_explicit5 = find_explicit(username, dislike_playlist5_id)

# %%
like_df['explicit'] = like_explicit
like_playlist2_df['explicit'] = like_explicit2
like_playlist3_df['explicit'] = like_explicit3
like_playlist4_df['explicit'] = like_explicit4
like_playlist5_df['explicit'] = like_explicit5

dislike_df['explicit'] = dislike_explicit
dislike_playlist2_df['explicit'] = dislike_explicit2
dislike_playlist3_df['explicit'] = dislike_explicit3
dislike_playlist4_df['explicit'] = dislike_explicit4
dislike_playlist5_df['explicit'] = dislike_explicit5

# %%
#Concatinate all df into like and dislike df
frames_like = [like_df, like_playlist2_df, like_playlist3_df, like_playlist4_df]
like_all_df = pd.concat(frames_like)

frames_dislike = [dislike_df, dislike_playlist2_df, dislike_playlist3_df,
                  dislike_playlist4_df, dislike_playlist5_df]
dislike_all_df = pd.concat(frames_dislike)
like_all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 316 entries, TIME to Can We Pretend (feat. Cash Cash)
# Data columns (total 20 columns):
# danceability        316 non-null float64
# energy              316 non-null float64
# key                 316 non-null int64
# loudness            316 non-null float64
# mode                316 non-null int64
# speechiness         316 non-null float64
# acousticness        316 non-null float64
# instrumentalness    316 non-null float64
# liveness            316 non-null float64
# valence             316 non-null float64
# tempo               316 non-null float64
# type                316 non-null object
# id                  316 non-null object
# uri                 316 non-null object
# track_href          316 non-null object
# analysis_url        316 non-null object
# duration_ms         316 non-null int64
# time_signature      316 non-null int64
# popularity          316 non-null int64
# explicit            316 non-null bool
# dtypes: bool(1), float64(9), int64(5), object(5)
# memory usage: 49.7+ KB

# %%
like_all_df = like_all_df.drop(columns=["analysis_url", "id", "track_href", "type", "uri"])
dislike_all_df = dislike_all_df.drop(columns=["analysis_url", "id", "track_href", "type", "uri"])

# %%
like_all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 316 entries, TIME to Can We Pretend (feat. Cash Cash)
# Data columns (total 16 columns):
# danceability        316 non-null float64
# energy              316 non-null float64
# key                 316 non-null int64
# loudness            316 non-null float64
# mode                316 non-null int64
# speechiness         316 non-null float64
# acousticness        316 non-null float64
# instrumentalness    316 non-null float64
# liveness            316 non-null float64
# valence             316 non-null float64
# tempo               316 non-null float64
# duration_ms         316 non-null int64
# time_signature      316 non-null int64
# popularity          316 non-null int64
# explicit            316 non-null bool
# like/dislike        316 non-null int64
# dtypes: bool(1), float64(9), int64(6)
# memory usage: 39.8+ KB

# %%
dislike_all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 353 entries, Electricity (with Dua Lipa) to What If I Never Get Over You
# Data columns (total 16 columns):
# danceability        353 non-null float64
# energy              353 non-null float64
# key                 353 non-null int64
# loudness            353 non-null float64
# mode                353 non-null int64
# speechiness         353 non-null float64
# acousticness        353 non-null float64
# instrumentalness    353 non-null float64
# liveness            353 non-null float64
# valence             353 non-null float64
# tempo               353 non-null float64
# duration_ms         353 non-null int64
# time_signature      353 non-null int64
# popularity          353 non-null int64
# explicit            353 non-null bool
# like/dislike        353 non-null int64
# dtypes: bool(1), float64(9), int64(6)
# memory usage: 44.5+ KB

# %%
like_all_df.head()
# Out:
#                       danceability  energy  key  loudness  mode  speechiness  \
# TIME                         0.768   0.808    5    -1.818     1       0.1120
# Falling - Radio Edit         0.446   0.928    0    -6.482     0       0.0907
# Space Between                0.702   0.595   11    -8.295     0       0.0356
# Higher                       0.472   0.881    6    -6.182     1       0.0491
# Together                     0.461   0.848    3    -5.065     1       0.0692
#
#                       acousticness  instrumentalness  liveness  valence  \
# TIME                       0.00627          0.000005    0.3430    0.664
# Falling - Radio Edit       0.00752          0.000019    0.5060    0.239
# Space Between              0.01220          0.472000    0.1080    0.483
# Higher                     0.00810          0.111000    0.3660    0.240
# Together                   0.09850          0.000051    0.0784    0.278
#
#                         tempo  duration_ms  time_signature  popularity  \
# TIME                  119.971       166000               4          63
# Falling - Radio Edit  127.012       230551               4          27
# Space Between         124.007       199921               5          21
# Higher                127.014       288189               4          54
# Together              128.009       287370               4          33
#
#                       explicit  like/dislike
# TIME                     False             1
# Falling - Radio Edit     False             1
# Space Between            False             1
# Higher                   False             1
# Together                 False             1

# %% [markdown]
# ## Visualizing

# %% [markdown]
# Now that we have loaded our dataframes and removed features that won't help with modeling, let's visualize these features and comapred them with the liked and disliked.

# %%
sns.distplot(like_all_df['acousticness'],color ='blue', label='likes')
sns.distplot(dislike_all_df['acousticness'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %% [markdown]
# We can see that both dataframes do not have much acousticness to their properties. This means that a future recommended song will probably not have much acoustiness to it.

# %%
sns.distplot(like_all_df['loudness'],color ='blue', label='likes')
sns.distplot(dislike_all_df['loudness'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %% [markdown]
# We can see for the loudness we have both disliked and liked songs that are in the negative zone, which means that these songs were't mixed or recorded with a high deceible.

# %%
sns.distplot(like_all_df['danceability'],color ='blue', label='likes')
sns.distplot(dislike_all_df['danceability'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %% [markdown]
# The distribution of liked danceable songs are mostly on 0.6, though there is a higher spread of disliked songs.

# %%
sns.distplot(like_all_df['energy'],color ='blue', label='likes')
sns.distplot(dislike_all_df['energy'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %% [markdown]
# It seems that most of the songs that I liked have high energy, which is about right. I tend to enjoy music that excites me. This will indicate that my model will have a higher weight on the song's energy to recommend me a new song.

# %%
sns.distplot(like_all_df['instrumentalness'],color ='blue', label='likes')
sns.distplot(dislike_all_df['instrumentalness'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %%
sns.distplot(like_all_df['liveness'],color ='blue', label='likes')
sns.distplot(dislike_all_df['liveness'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %% [markdown]
# There are more disliked songs that are in the 0.0 and 0.2 range, and for liked tracks they are spread on the scale.

# %%
sns.distplot(like_all_df['speechiness'],color ='blue', label='likes')
sns.distplot(dislike_all_df['speechiness'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %%
sns.distplot(like_all_df['valence'],color ='blue', label='likes')
sns.distplot(dislike_all_df['valence'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %% [markdown]
# There seem to be more valence in songs that I dislike. This is odd, because I tend to lean more towards songs that are cheerful and happy.

# %%
sns.distplot(like_all_df['time_signature'],color ='blue', label='likes')
sns.distplot(dislike_all_df['time_signature'], color ='r', label='dislikes')
plt.legend()
plt.show()

# %%
sns.distplot(like_all_df['popularity'], color='b', label='likes')
sns.distplot(dislike_all_df['popularity'], color='r', label='dislikes')
plt.legend()
plt.show()

# %% [markdown]
# ### Target Feature
# Before combining our dataframes, create a feature to set a target variable which tells the model if we like the song or not. We are going to create a binary feature, which state if we like the song then show 1 else 0.

# %%
# Add array of 1's to liked_df
like_all_df['like/dislike'] = [1] * (len(like_all_df))
dislike_all_df['like/dislike'] = [0] * (len(dislike_all_df))
like_all_df.head()
# Out:
#                       danceability  energy  key  loudness  mode  speechiness  \
# TIME                         0.768   0.808    5    -1.818     1       0.1120
# Falling - Radio Edit         0.446   0.928    0    -6.482     0       0.0907
# Space Between                0.702   0.595   11    -8.295     0       0.0356
# Higher                       0.472   0.881    6    -6.182     1       0.0491
# Together                     0.461   0.848    3    -5.065     1       0.0692
#
#                       acousticness  instrumentalness  liveness  valence  \
# TIME                       0.00627          0.000005    0.3430    0.664
# Falling - Radio Edit       0.00752          0.000019    0.5060    0.239
# Space Between              0.01220          0.472000    0.1080    0.483
# Higher                     0.00810          0.111000    0.3660    0.240
# Together                   0.09850          0.000051    0.0784    0.278
#
#                         tempo  duration_ms  time_signature  popularity  \
# TIME                  119.971       166000               4          63
# Falling - Radio Edit  127.012       230551               4          27
# Space Between         124.007       199921               5          21
# Higher                127.014       288189               4          54
# Together              128.009       287370               4          33
#
#                       explicit  like/dislike
# TIME                     False             1
# Falling - Radio Edit     False             1
# Space Between            False             1
# Higher                   False             1
# Together                 False             1

# %%
like_all_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 316 entries, TIME to Can We Pretend (feat. Cash Cash)
# Data columns (total 16 columns):
# danceability        316 non-null float64
# energy              316 non-null float64
# key                 316 non-null int64
# loudness            316 non-null float64
# mode                316 non-null int64
# speechiness         316 non-null float64
# acousticness        316 non-null float64
# instrumentalness    316 non-null float64
# liveness            316 non-null float64
# valence             316 non-null float64
# tempo               316 non-null float64
# duration_ms         316 non-null int64
# time_signature      316 non-null int64
# popularity          316 non-null int64
# explicit            316 non-null bool
# like/dislike        316 non-null int64
# dtypes: bool(1), float64(9), int64(6)
# memory usage: 39.8+ KB

# %%
#concate
train_frame = [like_all_df, dislike_all_df]
train_data = pd.concat(train_frame)
train_data.head()
# Out:
#                       danceability  energy  key  loudness  mode  speechiness  \
# TIME                         0.768   0.808    5    -1.818     1       0.1120
# Falling - Radio Edit         0.446   0.928    0    -6.482     0       0.0907
# Space Between                0.702   0.595   11    -8.295     0       0.0356
# Higher                       0.472   0.881    6    -6.182     1       0.0491
# Together                     0.461   0.848    3    -5.065     1       0.0692
#
#                       acousticness  instrumentalness  liveness  valence  \
# TIME                       0.00627          0.000005    0.3430    0.664
# Falling - Radio Edit       0.00752          0.000019    0.5060    0.239
# Space Between              0.01220          0.472000    0.1080    0.483
# Higher                     0.00810          0.111000    0.3660    0.240
# Together                   0.09850          0.000051    0.0784    0.278
#
#                         tempo  duration_ms  time_signature  popularity  \
# TIME                  119.971       166000               4          63
# Falling - Radio Edit  127.012       230551               4          27
# Space Between         124.007       199921               5          21
# Higher                127.014       288189               4          54
# Together              128.009       287370               4          33
#
#                       explicit  like/dislike
# TIME                     False             1
# Falling - Radio Edit     False             1
# Space Between            False             1
# Higher                   False             1
# Together                 False             1

# %%
#Plot correlation and see which features have a higher effect on our target variable
plt.figure(figsize=(16,16))
ax = sns.heatmap(train_data.corr(),annot=True , cmap='winter')

# %% [markdown]
# ## Modeling
# Now for the fun part. First we need to split out dataset into a train and test set. I am going to split the ratio to 70% training and 30% test.

# %%
train, test = train_test_split(train_data, test_size = 0.3, random_state = 42)
train.head()
# Out:
#                               danceability  energy  key  loudness  mode  \
# REDLIGHT                             0.611   0.931    4    -4.189     0
# Wanderer                             0.657   0.798    1    -5.341     0
# Don't Be so Hard on Yourself         0.571   0.815    6    -3.267     1
# Is It Love? (1001)                   0.657   0.486    6   -12.415     0
# I Feel It                            0.566   0.954    6    -4.678     1
#
#                               speechiness  acousticness  instrumentalness  \
# REDLIGHT                           0.3540       0.19800            0.0000
# Wanderer                           0.0411       0.02100            0.8390
# Don't Be so Hard on Yourself       0.0321       0.06080            0.0000
# Is It Love? (1001)                 0.0344       0.20200            0.9160
# I Feel It                          0.0376       0.00411            0.0257
#
#                               liveness  valence    tempo  duration_ms  \
# REDLIGHT                        0.4440   0.2250  129.903       135380
# Wanderer                        0.1360   0.0393  118.050       218168
# Don't Be so Hard on Yourself    0.1630   0.6640  120.008       211460
# Is It Love? (1001)              0.0795   0.3200  124.008       344027
# I Feel It                       0.0943   0.8870  125.967       155250
#
#                               time_signature  popularity  explicit  \
# REDLIGHT                                   3          58      True
# Wanderer                                   4          25     False
# Don't Be so Hard on Yourself               4          55     False
# Is It Love? (1001)                         4          42     False
# I Feel It                                  4          69     False
#
#                               like/dislike
# REDLIGHT                                 1
# Wanderer                                 1
# Don't Be so Hard on Yourself             0
# Is It Love? (1001)                       1
# I Feel It                                1

# %%
feats = ['acousticness', 'instrumentalness', 'liveness', 'loudness', 'energy', 
         'danceability', 'speechiness', 'valence', 'popularity', 'tempo']
X_train = train[feats]
y_train = train['like/dislike']
X_test = test[feats]
y_test = test['like/dislike']

# %% [markdown]
# ### Logistic Regression

# %%
#logistic regression
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
lr.score(X_test, y_test)
# Out:
# /Users/khalid/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.8258706467661692

# %% [markdown]
# ### K-nearest Neighbors

# %%
#KNeighbors
knn = KNeighborsClassifier(5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
knn.score(X_test, y_test)
# Out:
# 0.8805970149253731

# %% [markdown]
# ### Random Forest Classification

# %%
#RandomForest
rf = RandomForestClassifier(max_depth=5, n_estimators=100, max_features=5)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)
rf.score(X_test, y_test)
# Out:
# 0.8706467661691543

# %% [markdown]
# ### Decision Tree

# %%
#DecisonTree
dt = DecisionTreeClassifier(min_samples_split=50)
dt.fit(X_train, y_train)
y_pred = dt.predict(X_test)
dt.score(X_test, y_test)
# Out:
# 0.845771144278607

# %% [markdown]
# ### XGBoost

# %%
#Xgboost
xg = xgb.XGBClassifier(n_estimators=120, max_depth=20, learning_rate=0.5, subsample=0.5)
xg.fit(X_train, y_train)
y_pred = xg.predict(X_test)
xg.score(X_test, y_test)
# Out:
# 0.8905472636815921

# %% [markdown]
# ## Conclusion
# To conclude, the purpose of this project is to see whether I am able to predict new songs based on my music taste. To summarise what I have done, I will include my pipeline here:
#
# * Load liked and disliked playlist from Spotify's API using Spotipy Library.
# * Use track features to get more knowledge about these songs.
# * Clean data and feature engineer to help with modeling
# * EDA to understand whats going on with the data
# * Combine data into one dataframe
# * Split dataset into train and test
# * Champion challenge models
#
# Through this, I can start using machine learning to recommend new songs based on my taste. Though I am not sure how will this hold up based in my current dataset. To test this for other users, we will have to intake their liked and disliked playlists to be able to give them a better recommendation. Another way would be to pull infomation about liked and disliked songs that the user peroanlly assigns to their music library.
